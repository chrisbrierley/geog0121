# %% [markdown]
# ## Welcome to the Jupyter Notebook system
# Jupyter Notebooks are a way to create documents that have both interactive (REPL) code and documentation!  Jupyter works with Python, Julia, R, and many other languages. What this means is that we combine programming code along with its explanations and results. Where possible I will be using these Notebooks during the practical sessions.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Each cell in a notebook can be Markdown or code.
#  - [Enter] Puts you in cell-editing mode, and [Escape] brings you to document-editing mode.
#  - [Shift-Enter] Evaluates the cell.
#  - [M] Switches the cell to Markdown mode, and [Y] switches it to code.
#  - [H] Shows you help with other commands.

# %% [markdown]
# ## Programming in Python
# Each Jupyter Notebook runs in a particular programming language (called a kernel). Here we are using python (look up in the top right-hand corner). You can do calculations directly, such as:

# %%
1+5
# Out:
# 6

# %%
3 + 5
# Out:
# 8

# %% [markdown]
# Python is one of the main programming languages for geoscience today. Students who took the Scientific Computing module last term should know all about python. I therefore want to give them the opportunity to really get to grips with the material. Having said that, those of you who didn't take that course should be able to just click-a-long whilst editing a few cells here or there to alter some key inputs.

# %% [markdown]
# #### Packages
# Before you do much fun stuff you will need to load packages. This is done by using the import function. The conda enviroment geog0121 should have installed a load of useful climate-related packages for you.

# %%
import numpy as np

# %% [markdown]
# #### Accessing the terminal from Jupyter
# You can run a command in Jupyter just by putting a % in front of it. Do not rely too much on this approach, as it interacts with the kernal (instance of python underlying a notebook, rather than with all shells on the machine).

# %%
# !date
# Out:
# Wed 15 Jan 12:36:41 GMT 2020

# %% [markdown]
# ### Next...

# %% [markdown]
# if you are already familiar wth python and Jupyter Notebooks, you can head off now. Hopefully the geog0121 version of the notebooks has installed on your Desktop now.
#
# If you want to learn more about python and Jupyter, I recommend that you copy version of the intro_to_python.ipynb and numpy_and_matplotlib.ipynb from ~/geog0121/Read_only_notebooks and have a play with them. These were written Ryan Abernathy at Columbia University.
